# %%
import pandas as pd

state = pd.read_csv('null.csv')
print(state)
# Out:
#             State Patients Saved Dead Active Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                      State   Patients      Saved       Dead
# 1                                Maharashtra    1919550    1809948      49255
# 2                                  Karnataka     916256     891095      12062
# 3                             Andhra Pradesh     881061     870342       7094
# 4                                 Tamil Nadu     814170     793154      12069
# 5                                     Kerala     740517     672196       2977
# 6                                      Delhi     622851     605685      10453
# 7                              Uttar Pradesh     581980     558303       8306
# 8                                West Bengal     547443     524071       9598
# 9                                     Odisha     328504     324068       1914
# 10                                 Rajasthan     305360     291533       2670
# ...
